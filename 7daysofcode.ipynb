# %%
import pandas as pd
# %pip install pyarrow
# %pip install matplotlib
# %pip install seaborn
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
dados_2010_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20101.csv?raw=true')
dados_2010_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20102.csv?raw=true')
dados_2011_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20111.csv?raw=true')
dados_2011_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20112.csv?raw=true')
dados_2012_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20121.csv?raw=true')
dados_2012_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20122.csv?raw=true')
dados_2013_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20131.csv?raw=true')
dados_2013_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20132.csv?raw=true')
dados_2014_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20141.csv?raw=true')
dados_2014_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20142.csv?raw=true')
dados_2015_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20151.csv?raw=true')
dados_2015_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20152.csv?raw=true')
dados_2016_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20161.csv?raw=true')
dados_2016_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20162.csv?raw=true')
dados_2017_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20171.csv?raw=true')
dados_2017_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20172.csv?raw=true')
dados_2018_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20181.csv?raw=true')
dados_2018_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20182.csv?raw=true')
dados_2019_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20191.csv?raw=true')
dados_2019_2 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20192.csv?raw=true')
dados_2020_1 = pd.read_csv('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/blob/main/Dia_1-Importando_dados/Datasets/dados_emprestimos/emprestimos-20201.csv?raw=true')

# %%
dados_2020_1
# Out:
#        id_emprestimo codigo_barras                 data_renovacao  \
# 0            2962509    2007005628                            NaN
# 1            2962510       L202802                            NaN
# 2            2962511    2012008328                            NaN
# 3            2962512    2012055016  2020/01/17 09:56:18.380000000
# 4            2962513       L197391  2020/01/17 23:50:18.862000000
# ...              ...           ...                            ...
# 26556        2989086    2008047044                            NaN
# 26557        2989087    2008047047                            NaN
# 26558        2989088    2010052905                            NaN
# 26559        2989089    2010048023                            NaN
# 26560        2989090    2013106838                            NaN
#
#                      data_emprestimo                 data_devolucao  \
# 0      2020/01/02 08:17:30.290000000  2020/01/07 11:14:07.000000000
# ...

# %%
emprestimos_bib = pd.concat([dados_2010_1,dados_2010_2,dados_2011_1,dados_2011_2,dados_2012_1,dados_2012_2,dados_2013_1,dados_2013_2,dados_2014_1,
                                    dados_2014_2,dados_2015_1,dados_2015_2,dados_2016_1,dados_2016_2,dados_2017_1,dados_2017_2,dados_2018_1,dados_2018_2,
                                    dados_2019_1,dados_2019_2,dados_2020_1],ignore_index=True)

# %%
emprestimos_bib
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709684       L095049                            NaN
# ...                ...           ...                            ...
# 2258013        2989086    2008047044                            NaN
# 2258014        2989087    2008047047                            NaN
# 2258015        2989088    2010052905                            NaN
# 2258016        2989089    2010048023                            NaN
# 2258017        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos_bib.value_counts()
# Out:
# id_emprestimo  codigo_barras  data_renovacao                 data_emprestimo                data_devolucao                 matricula_ou_siape  tipo_vinculo_usuario
# 709704         2006021442     2010/01/17 18:56:43.923000000  2010/01/04 09:58:46.522000000  2010/02/01 13:59:02.528000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709705         2009032168     2010/01/17 18:56:43.909000000  2010/01/04 09:58:46.549000000  2010/01/20 13:14:34.464000000  2.008010e+09        ALUNO DE GRADUAÇÃO        7
# 709698         2009047725     2010/01/18 14:44:41.163000000  2010/01/04 09:21:19.099000000  2010/02/02 12:02:38.444000000  2.009047e+09        ALUNO DE GRADUAÇÃO        3
# 709686         2006017618     2010/01/26 08:07:01.738000000  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000  2.008112e+09        ALUNO DE PÓS-GRADUAÇÃO    2
# ...

# %%
emprestimos_bib = emprestimos_bib.drop_duplicates()

# %%
emprestimos_bib.head()
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
# 3         709687       L184117  2010/01/18 11:07:46.470000000
# 8         709688    2007027500  2010/01/19 15:59:26.464000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
# 3  2010/01/04 08:24:21.284000000  2010/02/03 08:58:45.692000000
# 8  2010/01/04 08:27:33.569000000  2010/02/03 13:06:30.662000000
#
#    matricula_ou_siape    tipo_vinculo_usuario
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO
# ...

# %%
dados_exemplares = pd.read_parquet('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_1-Importando_dados/Datasets/dados_exemplares.parquet')
dados_exemplares
# Out:
#         id_exemplar codigo_barras            colecao  \
# index
# 0                 5       L000003  Acervo Circulante
# 1                 4       L000002  Acervo Circulante
# 2                 3       L000001  Acervo Circulante
# 3                 7       L000114  Acervo Circulante
# 5                10       L000041  Acervo Circulante
# ...             ...           ...                ...
# 568580      1353472    2021011150  Acervo Circulante
# 568581      1353473    2019013454  Acervo Circulante
# 568582      1353474    2019012811  Acervo Circulante
# 568583      1353475    2019013451  Acervo Circulante
# 568584      1353476    2019012276  Acervo Circulante
#
#                                                biblioteca status_material  \
# index
# 0                          Biblioteca Central Zila Mamede         REGULAR
# 1                          Biblioteca Central Zila Mamede         REGULAR
# 2                          Biblioteca Central Zila Mamede        ESPECIAL
# ...

# %%
emprestimos = emprestimos_bib.merge(dados_exemplares)
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                        data_emprestimo                 data_devolucao  \
# 0        2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# ...

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#    matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0        2.008023e+09      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1        2.008023e+09      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2        2.008112e+09  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# **DIA 2**
# Excluindo a coluna "registro_sistema" pois a mesma nao faz sentido para a análise por podemos exclui-la.
# Já a coluna da matricula (“matricula_ou_siape”) não está com um formato muito legível, vamos transforma-la em string

# %%
emprestimos['matricula_ou_siape'] = emprestimos['matricula_ou_siape'].astype(str)

# %%
emprestimos = emprestimos.drop('registro_sistema', axis=1)

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# Criando a coluna de acordo com a Classificação Decimal Universal abaixo:
#
# 000 a 099: Generalidades. Ciência e conhecimento.
#
# 100 a 199: Filosofia e psicologia.
#
# 200 a 299: Religião.
#
# 300 a 399: Ciências sociais.
#
# 400 a 499: Classe vaga. Provisoriamente não ocupada.
#
# 500 a 599: Matemática e ciências naturais.
#
# 600 a 699: Ciências aplicadas.
#
# 700 a 799: Belas artes.
#
# 800 a 899: Linguagem, língua, linguística.
#
# 900 a 999: Geografia, biografia, história.
#
# No campo "localização", temos um código numérico referente a essa classificação. Portanto, iremos criar uma nova coluna que refletirá a localização por extenso, de acordo com a classificação.

# %%
cdu_lista = []
for cdu in emprestimos['localizacao']:
    if cdu < 100:
        cdu_lista.append('Generalidades')
    elif cdu < 200:
        cdu_lista.append('Filosofia e Psicologia')
    elif cdu < 300:
        cdu_lista.append('Religiao')
    elif cdu < 400:
        cdu_lista.append('Ciências sociais.')
    elif cdu < 500:
        cdu_lista.append('Classe vaga')
    elif cdu < 600:
        cdu_lista.append('Matemática e ciências naturais')
    elif cdu < 700:
        cdu_lista.append('Ciências aplicadas')
    elif cdu < 800:
        cdu_lista.append('Belas artes')
    elif cdu < 900:
        cdu_lista.append('Linguagem, língua, linguística')
    else:
        cdu_lista.append('Geografia, biografia, história')
    
emprestimos['CDU'] = cdu_lista

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#                  data_emprestimo                 data_devolucao  \
# 0  2010/01/04 07:44:10.721000000  2010/01/05 16:26:12.662000000
# 1  2010/01/04 07:44:10.750000000  2010/01/12 07:34:13.934000000
# 2  2010/01/04 08:08:44.081000000  2010/02/25 07:36:25.800000000
#
#   matricula_ou_siape    tipo_vinculo_usuario  id_exemplar            colecao  \
# 0       2008023265.0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1       2008023265.0      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2       2008112114.0  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %% [markdown]
# **DIA 3**
#
# A diretoria da biblioteca gostaria de entender se a quantidade de empréstimos está diminuindo, aumentando ou permanecendo igual ao decorrer dos últimos anos.

# %%
emprestimos['data_emprestimo'] = pd.to_datetime(emprestimos['data_emprestimo'], errors='coerce')
emprestimos['data_devolucao'] = pd.to_datetime(emprestimos['data_devolucao'], errors='coerce')

# %%
emprestimos['ano_emprestimo'] = emprestimos['data_emprestimo'].dt.year
emprestimos
# Out:
#          id_emprestimo codigo_barras                 data_renovacao  \
# 0               709684       L095049                            NaN
# 1               709685       L167050                            NaN
# 2               709686    2006017618  2010/01/26 08:07:01.738000000
# 3               709687       L184117  2010/01/18 11:07:46.470000000
# 4               709688    2007027500  2010/01/19 15:59:26.464000000
# ...                ...           ...                            ...
# 2072517        2989086    2008047044                            NaN
# 2072518        2989087    2008047047                            NaN
# 2072519        2989088    2010052905                            NaN
# 2072520        2989089    2010048023                            NaN
# 2072521        2989090    2013106838                            NaN
#
#                 data_emprestimo          data_devolucao matricula_ou_siape  \
# ...

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800       2008112114.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %%
quantidade_exemplares_ano = emprestimos.groupby('ano_emprestimo')['id_exemplar'].count()

# %%
quantidade_exemplares_ano
# Out:
# ano_emprestimo
# 2010    161394
# 2011    196390
# 2012    221365
# 2013    234749
# 2014    219189
# 2015    213582
# 2016    215900
# 2017    218462
# 2018    194080
# 2019    171801
# 2020     25610
# Name: id_exemplar, dtype: int64

# %%
quantidade_exemplares_ano.plot.bar(
    xlabel='Ano',
    ylabel='Quantidade de Exemplares Emprestados',
    title='Empréstimos por Ano',
    figsize=(10, 5)
)
# Out:
# <Axes: title={'center': 'Empréstimos por Ano'}, xlabel='Ano', ylabel='Quantidade de Exemplares Emprestados'>

# %% [markdown]
# ## Análises
#
# - Os dados de empréstimos vinham crescendo até **2013**. Após esse ano, houve uma **queda constante**, com exceção de uma leve recuperação em **2017**.
#
# - **2013** foi o ano com **maior número de empréstimos**, o que indica que pode ter havido ações específicas que incentivaram os alunos a procurarem mais exemplares. Vale a pena investigar **quais estratégias foram adotadas nesse ano**.
#
# - Em **2018 e 2019**, observa-se o início de uma **queda mais acentuada**, possivelmente relacionada ao avanço tecnológico, ao uso intensivo de **celulares e redes sociais**, e à transição para conteúdos digitais.
#
# - Em **2020**, temos dados apenas do **primeiro semestre**. Ainda assim, é possível prever uma **queda drástica nos empréstimos** devido ao impacto da **pandemia da COVID-19**, que resultou no fechamento temporário de bibliotecas e instituições de ensino.
#
# # Aprofundamento
#
# -A queda de 2013 a 2020 pode ter sido influenciada pela transição dos livros fisicos para os livros digitais e biblotecas digitais

# %% [markdown]
# A diretoria também gostaria de gerenciar melhor os recursos humanos da biblioteca de acordo com a demanda de trabalho existente. Por exemplo:
#
#
# gerenciar a programação de férias dos colaboradores de acordo com os meses de menor demanda;
# programar atividades que não sejam de atendimento ao usuário para períodos específicos de menor demanda.
#
# Há uma suspeita interna de que os meses com maior número de exemplares emprestados sejam março e setembro, mas não foi realizada uma análise real sobre isso.

# %%
emprestimos['mes_emprestimo'] = emprestimos['data_emprestimo'].dt.month

# %%
quantidade_exemplares_mes = emprestimos.groupby('mes_emprestimo')['id_exemplar'].count()

# %%
quantidade_exemplares_mes.plot(
    kind='line',
    xlabel='Mês',
    ylabel='Quantidade de Exemplares Emprestados',
    title='Empréstimos por Mês',
    figsize=(20, 4)
)
# Out:
# <Axes: title={'center': 'Empréstimos por Mês'}, xlabel='Mês', ylabel='Quantidade de Exemplares Emprestados'>

# %% [markdown]
# ## Análise do Gráfico de Empréstimos por Mês
#
# Ao analisar o gráfico de empréstimos mensais, é possível identificar claramente os períodos de maior e menor demanda na biblioteca ao longo do ano. Os meses com menor quantidade de exemplares emprestados representam oportunidades ideais para o gerenciamento interno da equipe.
#
# **Sugestões para a Programação de Férias e Atividades Internas:**
#
# - **Programação de Férias:**
#   Recomenda-se que as férias dos colaboradores sejam preferencialmente agendadas para os meses de menor demanda(1,6,7,12), conforme indicado pelo gráfico. Dessa forma, a ausência de funcionários terá menor impacto no atendimento ao usuário.
#
# - **Atividades Não Relacionadas ao Atendimento:**
#   Atividades como inventário, organização do acervo, treinamentos internos e manutenção podem ser planejadas para esses mesmos períodos de baixa demanda. Assim, é possível otimizar o tempo da equipe sem prejudicar o serviço ao público.
#
# **Conclusão:**
# O uso do gráfico permite uma gestão mais eficiente dos recursos humanos, garantindo que o atendimento ao usuário não seja comprometido nos períodos de maior movimento e que as atividades internas sejam realizadas de forma estratégica nos meses mais tranquilos.

# %% [markdown]
# Além do gerenciamento anual das atividades, a diretoria também necessita que seja planejada uma programação diária das atividades. Por este motivo, verifique quais foram os horários com maior quantidade de empréstimos ao longo de um dia inteiro.

# %%
emprestimos['hora_emprestimo'] = emprestimos['data_emprestimo'].dt.hour

# %%
quantidade_exemplares_hora = emprestimos.groupby('hora_emprestimo')['id_exemplar'].count()
quantidade_exemplares_hora.plot(
    kind='line',
    xlabel='Hora',
    ylabel='Quantidade de Exemplares Emprestados',
    title='Empréstimos por Hora',
    figsize=(10, 5)
)
# Out:
# <Axes: title={'center': 'Empréstimos por Hora'}, xlabel='Hora', ylabel='Quantidade de Exemplares Emprestados'>

# %% [markdown]
# ## Análise dos Empréstimos por Hora
#
# O gráfico de empréstimos por hora mostra claramente que a demanda na biblioteca é significativamente maior entre 8h e 18h, com picos notáveis por volta das 10h, 15h e 17h. Fora desse intervalo, especialmente antes das 8h e após as 20h, o número de empréstimos é muito baixo ou praticamente inexistente.
#
# **Horários de Maior Movimento:**
# - Entre 8h e 18h, com destaque para os picos próximos das 10h, 15h e 17h.
#
# **Horários de Menor Movimento:**
# - proximo das 8h e das 20h, a quantidade de empréstimos é mínima.
#
# ### Recomendações para Alocação de Atividades Internas
#
# - **Atividades que não envolvem atendimento ao usuário** (como inventário, organização do acervo, treinamentos e manutenção) devem ser preferencialmente realizadas nos horários de menor movimento, ou seja, proximo as 8h e 20h.
# - Caso não seja possível realizar essas atividades fora do horário de pico, recomenda-se priorizar os intervalos entre 12h e 14h, quando há uma leve redução na demanda.

# %% [markdown]
# **DIA 4**
#
# alguns questionamentos serão pertinentes para a diretoria das bibliotecas, como:
#
#
# “Como se distribuem os empréstimos de exemplares pelos tipos de vínculo dos usuários?”
# Desta forma, a diretoria poderá entender qual é o público que está utilizando a biblioteca e assim tomar decisões em continuar com a estratégia de negócio atual ou modificá-la.
#
# Quais coleções são mais emprestadas?
# Da mesma forma, as coleções. Ranquear as coleções mais emprestadas pelo público, será bastante importante para a estratégia atual.
#
# Quais são as bibliotecas com mais ou menos quantidade de empréstimos?
# Assim, a diretoria conseguirá entender onde ela deverá melhorar e focar suas iniciativas.

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800       2008112114.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %%
emprestimos['data_emprestimo'] = pd.to_datetime(emprestimos['data_emprestimo'])

# %%
emprestimos.tipo_vinculo_usuario.unique()
# Out:
# array(['ALUNO DE GRADUAÇÃO', 'ALUNO DE PÓS-GRADUAÇÃO', 'DOCENTE',
#        'SERVIDOR TÉCNICO-ADMINISTRATIVO', 'DOCENTE EXTERNO',
#        'ALUNO MÉDIO/TÉCNICO', 'USUÁRIO EXTERNO', 'OUTROS'], dtype=object)

# %%
emprestimos.colecao.unique()
# Out:
# array(['Acervo Circulante', 'Folhetos', 'Teses', 'Dissertações',
#        'Monografias', 'Publicações de Autores do RN',
#        'Publicações da UFRN', 'Multimeios', 'Coleção Mossoroense',
#        'Eventos', 'Trabalho Acadêmico', 'Obras de Referência',
#        'Obras Raras', 'Literatura de Cordel', 'Coleção Zila Mamede',
#        'Necessidades Educacionais Específicas'], dtype=object)

# %%
emprestimos.biblioteca.unique()
# Out:
# array(['Biblioteca Central Zila Mamede',
#        'Biblioteca Setorial Prof. Rodolfo Helinski - Escola Agrícola de Jundiaí - EAJ  - Macaiba',
#        'Biblioteca Setorial Bertha Cruz Enders - \xadEscola de Saúde da UFRN - ESUFRN',
#        'Biblioteca Setorial do Centro Ciências da Saúde - CCS',
#        'Biblioteca Setorial Prof. Alberto Moreira Campos - \xadDepartamento de Odontologia',
#        'Biblioteca Setorial Prof. Ronaldo Xavier de Arruda - CCET',
#        'Biblioteca Setorial do Centro de Ciências Humanas, Letras e Artes - CCHLA',
#        'Biblioteca Setorial Prof. Horácio Nicolas Solimo - \xad Engenharia Química - EQ - CT',
#        'Biblioteca Setorial Prof. Francisco Gurgel De Azevedo - Instituto Química - IQ',
#        'Biblioteca Setorial do Centro Ciências Sociais Aplicadas - CCSA',
#        'Biblioteca Setorial do Departamento de Artes - DEART',
#        'Biblioteca Setorial Prof. Dr. Marcelo Bezerra de Melo Tinôco - DARQ - \xadCT',
# ...

# %%
emprestimos.CDU.unique()
# Out:
# array(['Ciências aplicadas', 'Linguagem, língua, linguística',
#        'Ciências sociais.', 'Geografia, biografia, história',
#        'Matemática e ciências naturais', 'Religiao', 'Generalidades',
#        'Filosofia e Psicologia', 'Belas artes'], dtype=object)

# %%
def tabela_frequencia(variavel):


  dataframe = pd.DataFrame(emprestimos[variavel].value_counts())                      
  dataframe.columns = ['quantidade']
  dataframe['percentual'] = round((dataframe.quantidade / dataframe.quantidade.sum())*100,1)

  return dataframe


"""
Esta função eu não estava conseguindo fazer, tive que pedir ajuda a uma inteligencia artificial.
"""
# Out:
# '\nEsta função eu não estava conseguindo fazer, tive que pedir ajuda a uma inteligencia artificial.\n'

# %%
tabela_frequencia('tipo_vinculo_usuario')
# Out:
#                                  quantidade  percentual
# tipo_vinculo_usuario
# ALUNO DE GRADUAÇÃO                  1612324        77.8
# ALUNO DE PÓS-GRADUAÇÃO               302541        14.6
# DOCENTE                               70981         3.4
# SERVIDOR TÉCNICO-ADMINISTRATIVO       32184         1.6
# ALUNO MÉDIO/TÉCNICO                   28029         1.4
# DOCENTE EXTERNO                       23949         1.2
# USUÁRIO EXTERNO                        2509         0.1
# OUTROS                                    5         0.0

# %% [markdown]
# ## Análise do Público da Biblioteca
#
# Percebe-se que o maior público da biblioteca são os alunos de graduação, responsáveis pela grande maioria dos empréstimos (78%). Em seguida, aparecem os alunos de pós-graduação e, por último, os demais grupos, com um número bem menor de empréstimos.
#
# ### Insights Importantes
#
# - **Por que os alunos de pós-graduação não utilizam tanto os livros?**
#   Possíveis motivos incluem a alta demanda de leitura de artigos científicos, falta de tempo devido a outras atividades como trabalho ou compromissos da própria pós-graduação.
#
# - **Alto incentivo aos alunos de graduação:**
#   Os docentes costumam incentivar fortemente os alunos de graduação a utilizarem o acervo, o que pode explicar a alta demanda desse grupo.
#
# Esses pontos podem ajudar a direcionar estratégias para aumentar o engajamento de outros públicos e otimizar o uso dos recursos da biblioteca.

# %%
tabela_frequencia('colecao')
# Out:
#                                        quantidade  percentual
# colecao
# Acervo Circulante                         2053120        99.1
# Multimeios                                   7954         0.4
# Monografias                                  4021         0.2
# Dissertações                                 2406         0.1
# Obras de Referência                          1954         0.1
# Publicações de Autores do RN                  866         0.0
# Publicações da UFRN                           764         0.0
# Teses                                         714         0.0
# Folhetos                                      271         0.0
# Necessidades Educacionais Específicas         130         0.0
# Trabalho Acadêmico                            115         0.0
# Eventos                                       101         0.0
# Coleção Mossoroense                            44         0.0
# Coleção Zila Mamede                            30         0.0
# ...

# %% [markdown]
# ## Insights sobre as Coleções Mais Emprestadas
#
# A análise da tabela de frequência das coleções revela que a grande maioria dos empréstimos (99,1%) está concentrada no **Acervo Circulante**. As demais coleções representam uma parcela muito pequena do total de empréstimos, sendo que a segunda coleção mais emprestada, **Multimeios**, corresponde a apenas 0,4%.
#
# ### Principais Insights
#
# - **Foco no Acervo Circulante:**
#   O Acervo Circulante é, de longe, o mais utilizado pelos usuários da biblioteca. Isso indica que os livros e materiais dessa coleção são os mais relevantes para o público, devendo ser priorizados em investimentos, reposições e atualizações.
#
# - **Baixa Utilização das Outras Coleções:**
#   Coleções como Multimeios, Monografias, Dissertações e Obras de Referência têm uma participação muito pequena nos empréstimos. Isso pode indicar que esses materiais são menos procurados, possivelmente por serem de uso mais restrito, consulta local, ou por falta de divulgação.
#
# - **Oportunidade para Divulgação:**
#   As coleções especiais, como Obras Raras, Literatura de Cordel e Coleções Regionais, apresentam números quase insignificantes de empréstimos. A biblioteca pode investir em ações de divulgação e projetos para incentivar o uso e valorização desses acervos.
#
#
# ### Recomendações
#
# - **Manter e atualizar o Acervo Circulante, pois é o principal responsável pelo atendimento às demandas dos usuários.**
# - **Promover campanhas e eventos para aumentar a visibilidade das coleções menos utilizadas.**
# - **Avaliar a necessidade de ampliar ou adaptar o acervo de necessidades educacionais específicas para melhor atender esse público.**
# - **Investir em estratégias de engajamento para valorizar as coleções especiais e regionais, promovendo a cultura local e a diversidade do acervo.**

# %%
tabela_frequencia('biblioteca')
# Out:
#                                                     quantidade  percentual
# biblioteca
# Biblioteca Central Zila Mamede                         1426122        68.8
# Biblioteca Setorial do Centro Ciências da Saúde...      118614         5.7
# Biblioteca Setorial da Faculdade de Ciências da...       77609         3.7
# Biblioteca Setorial Prof. Alberto Moreira Campo...       66447         3.2
# Biblioteca Setorial Profª. Maria Lúcia da Costa...       61478         3.0
# Biblioteca Setorial Bertha Cruz Enders - ­Escol...       46040         2.2
# Biblioteca Setorial do Centro de Ciências Human...       40744         2.0
# Biblioteca Setorial Dr. Paulo Bezerra - EMCM/RN...       32097         1.5
# Biblioteca Setorial Profª. Maria José Mamede Ga...       29089         1.4
# Biblioteca Setorial Prof. Rodolfo Helinski - Es...       27219         1.3
# Biblioteca Setorial Prof. Francisco Gurgel De A...       26923         1.3
# ...

# %% [markdown]
# ## Análise dos Empréstimos por Biblioteca
#
# A tabela mostra que a **Biblioteca Central Zila Mamede** concentra a maior parte dos empréstimos, com 68,8% do total, muito à frente das demais bibliotecas. As bibliotecas setoriais, mesmo as mais movimentadas, apresentam percentuais bem menores, variando entre 5,7% e 0,0%.
#
# ### Principais Insights
#
# - **Centralização dos Empréstimos:**
#   A maior parte dos empréstimos ocorre na biblioteca central, indicando que ela é o principal polo de atendimento e circulação de acervo da instituição.
#
# - **Desbalanceamento entre Bibliotecas:**
#   Algumas bibliotecas setoriais, como a do Centro de Ciências da Saúde (CCS) e FACISA, possuem participação relevante, mas ainda assim muito inferior à central. Outras bibliotecas apresentam movimentação bastante reduzida.
#
# ### Recomendações
#
# - **Investir na infraestrutura e acervo da Biblioteca Central Zila Mamede, mantendo sua capacidade de atendimento.**
# - **Realizar diagnósticos nas bibliotecas setoriais com menor movimento para identificar possíveis causas e oportunidades de melhoria.**

# %%
tabela_frequencia('CDU')
# Out:
#                                 quantidade  percentual
# CDU
# Ciências aplicadas                 1425473        68.8
# Ciências sociais.                   369536        17.8
# Matemática e ciências naturais       68744         3.3
# Generalidades                        62521         3.0
# Religiao                             62295         3.0
# Filosofia e Psicologia               60563         2.9
# Geografia, biografia, história        7989         0.4
# Belas artes                           7911         0.4
# Linguagem, língua, linguística        7490         0.4

# %% [markdown]
# ## Análise dos Empréstimos por Classificação Decimal Universal (CDU)
#
# A tabela mostra que a maior parte dos empréstimos está concentrada em **Ciências Aplicadas** (68,8%), seguida por **Ciências Sociais** (17,8%). As demais áreas apresentam percentuais significativamente menores.
#
# ### Principais Insights
#
# - **Predomínio das Ciências Aplicadas:**
#   A categoria de Ciências Aplicadas é a mais procurada pelos usuários, indicando uma forte demanda por livros e materiais dessa área. Isso pode refletir o perfil dos cursos e interesses acadêmicos da instituição.
#
# - **Relevância das Ciências Sociais:**
#   Ciências Sociais também apresentam uma participação expressiva nos empréstimos, sendo a segunda área mais buscada.
#
# - **Baixa Circulação em Outras Áreas:**
#   Áreas como Matemática e Ciências Naturais, Generalidades, Religião, Filosofia e Psicologia, Geografia, Belas Artes e Linguagem têm uma participação muito pequena nos empréstimos. Isso pode indicar menor interesse, menor oferta de títulos ou necessidade de maior divulgação desses acervos.
#
# ### Recomendações
#
# - **Priorizar investimentos e atualização do acervo em Ciências Aplicadas e Ciências Sociais, pois são as áreas de maior demanda.**
# - **Realizar campanhas para promover o uso dos acervos de áreas menos procuradas, incentivando a diversidade de leitura e pesquisa.**

# %% [markdown]
# **DIA 4**
# Você vai fazer dois recortes em seus dados para entender como eles se distribuíram ao decorrer desses anos e, desta forma, possa trazer inferências para levar à diretoria da biblioteca, a fim de que eles possam tomar decisões para o ano atual.
#
# Para isso, você vai avaliar dentre os alunos de graduação e pós graduação a distribuição de empréstimos mensais por ano realizados entre 2010 e 2020 da coleção que tiver a maior frequência de empréstimos.
#
# Plote um gráfico para cada tipo de usuário.
# Tenha um boxplots para cada ano e analise o que ocorreu.

# %%
emprestimos.head(3)
# Out:
#    id_emprestimo codigo_barras                 data_renovacao  \
# 0         709684       L095049                            NaN
# 1         709685       L167050                            NaN
# 2         709686    2006017618  2010/01/26 08:07:01.738000000
#
#           data_emprestimo          data_devolucao matricula_ou_siape  \
# 0 2010-01-04 07:44:10.721 2010-01-05 16:26:12.662       2008023265.0
# 1 2010-01-04 07:44:10.750 2010-01-12 07:34:13.934       2008023265.0
# 2 2010-01-04 08:08:44.081 2010-02-25 07:36:25.800       2008112114.0
#
#      tipo_vinculo_usuario  id_exemplar            colecao  \
# 0      ALUNO DE GRADUAÇÃO        13259  Acervo Circulante
# 1      ALUNO DE GRADUAÇÃO        70865  Acervo Circulante
# 2  ALUNO DE PÓS-GRADUAÇÃO       195347  Acervo Circulante
#
#                                           biblioteca status_material  \
# 0                     Biblioteca Central Zila Mamede         REGULAR
# ...

# %%
alunos_graduacao = emprestimos.query('tipo_vinculo_usuario == "ALUNO DE GRADUAÇÃO"')
alunos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        1600155
# Multimeios                                  4652
# Monografias                                 3572
# Dissertações                                1152
# Obras de Referência                         1047
# Publicações de Autores do RN                 595
# Publicações da UFRN                          466
# Teses                                        245
# Folhetos                                     180
# Trabalho Acadêmico                            81
# Necessidades Educacionais Específicas         73
# Eventos                                       57
# Coleção Mossoroense                           17
# Coleção Zila Mamede                           15
# Literatura de Cordel                          11
# Obras Raras                                    6
# Name: count, dtype: int64

# %%
alunos_graduacao_acervo_circulante = alunos_graduacao.query('colecao == "Acervo Circulante"')
alunos_graduacao_acervo_circulante = pd.DataFrame(alunos_graduacao_acervo_circulante)
alunos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_graduacao_acervo_circulante['data_emprestimo'])
alunos_graduacao_acervo_circulante['ano'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_graduacao_acervo_circulante['mes'] = alunos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_graduacao_acervo_circulante = alunos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2012    3       22797
# 1    2015    3       22483
# 2    2013    4       21853
# 3    2017    3       21735
# 4    2016    3       21692
# ..    ...  ...         ...
# 118  2016    1        2670
# 119  2019    1        2276
# 120  2019   12        1980
# 121  2020    1        1781
# 122  2011    1         809
#
# [123 rows x 3 columns]

# %%
from matplotlib import ticker

def gera_box_plot(dataset, x, y, titulo, subtitulo):
    '''
    Esta função irá gerar um gráfico de boxplot.
    '''
    sns.set_theme(style="darkgrid", palette='Blues', font_scale=1.3)
    plt.figure(figsize=(16,10))
    ax = sns.boxplot(y=y, x=x, data=dataset, color='#4171EF')
    ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, p: format(int(x), ',').replace(',','.')))
    plt.ylim(0, max(dataset[y])*1.1)
    plt.xlabel(None)
    plt.ylabel(None)
    ax.set_title(titulo+"\n", size=20, loc='left', weight='bold')
    ax.text(s=subtitulo, x=-0.5, y=max(dataset[y])*1.11, fontsize=18, ha='left', color='gray')

# %%
gera_box_plot(alunos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de graduação no acervo circulante')

# %% [markdown]
# ## Análise da Distribuição dos Empréstimos Mensais (Alunos de Graduação - Acervo Circulante)
#
# O boxplot mostra a variação mensal dos empréstimos realizados por alunos de graduação no acervo circulante entre 2010 e 2020.
#
# ### Principais Observações
#
# - **Crescimento até 2013:**
#   Nota-se um aumento consistente na mediana e na dispersão dos empréstimos mensais até 2013, indicando crescimento da demanda nesse período.
#
# - **Estabilidade e Queda Gradual:**
#   Após 2013, a mediana dos empréstimos começa a diminuir gradualmente, com maior estabilidade entre 2014 e 2018, mas já apresentando sinais de queda.
#
# - **Redução Acentuada em 2019 e 2020:**
#   A partir de 2019, observa-se uma redução mais acentuada, culminando em 2020 com o menor volume de empréstimos do período analisado. Isso pode estar relacionado à pandemia de COVID-19 e à suspensão das atividades presenciais.
#
# - **Variação Mensal:**
#   A dispersão dos dados (altura das caixas e presença de outliers) mostra que há meses com volumes de empréstimos significativamente acima ou abaixo da média, sugerindo sazonalidade ou eventos específicos que impactaram a demanda.

# %%
alunos_pos_graduacao = emprestimos.query('tipo_vinculo_usuario == "ALUNO DE PÓS-GRADUAÇÃO"')
alunos_pos_graduacao.colecao.value_counts()
# Out:
# colecao
# Acervo Circulante                        299201
# Dissertações                                934
# Obras de Referência                         700
# Multimeios                                  559
# Teses                                       367
# Monografias                                 278
# Publicações de Autores do RN                204
# Publicações da UFRN                         121
# Folhetos                                     60
# Necessidades Educacionais Específicas        30
# Eventos                                      26
# Coleção Mossoroense                          23
# Trabalho Acadêmico                           23
# Coleção Zila Mamede                          11
# Literatura de Cordel                          4
# Name: count, dtype: int64

# %%
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao.query('colecao == "Acervo Circulante"')
alunos_pos_graduacao_acervo_circulante = pd.DataFrame(alunos_pos_graduacao_acervo_circulante)
alunos_pos_graduacao_acervo_circulante['data_emprestimo'] = pd.to_datetime(alunos_pos_graduacao_acervo_circulante['data_emprestimo'])
alunos_pos_graduacao_acervo_circulante['ano'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.year
alunos_pos_graduacao_acervo_circulante['mes'] = alunos_pos_graduacao_acervo_circulante['data_emprestimo'].dt.month
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.loc[:,['ano','mes']]
alunos_pos_graduacao_acervo_circulante = alunos_pos_graduacao_acervo_circulante.value_counts().to_frame('quantidade').reset_index()
alunos_pos_graduacao_acervo_circulante
# Out:
#       ano  mes  quantidade
# 0    2015    3        3927
# 1    2017    8        3837
# 2    2017    3        3722
# 3    2016    3        3711
# 4    2016    8        3662
# ..    ...  ...         ...
# 119  2020    1        1143
# 120  2010    1        1105
# 121  2019   12        1069
# 122  2011    1         465
# 123  2020    6           2
#
# [124 rows x 3 columns]

# %%
gera_box_plot(alunos_pos_graduacao_acervo_circulante,'ano','quantidade','Distribuição dos empréstimos mensais', 'Realizados pelos alunos de pós-graduação no acervo circulante')

# %% [markdown]
# ## Análise da Distribuição dos Empréstimos Mensais (Alunos de Pós-Graduação - Acervo Circulante)
#
# O boxplot apresenta a variação mensal dos empréstimos realizados por alunos de pós-graduação no acervo circulante entre 2010 e 2020.
#
# ### Principais Observações
#
# - **Crescimento até 2013:**
#   Observa-se um aumento gradual na mediana dos empréstimos mensais até 2013, indicando maior engajamento desse público nesse período.
#
# - **Estabilidade entre 2013 e 2017:**
#   Entre 2013 e 2017, a mediana e a dispersão dos empréstimos permanecem relativamente estáveis, sugerindo um padrão de uso consistente pelos alunos de pós-graduação.
#
# - **Queda a partir de 2018:**
#   A partir de 2018, nota-se uma redução na mediana e na dispersão dos empréstimos, com queda mais acentuada em 2019 e principalmente em 2020, possivelmente devido à pandemia de COVID-19 e à suspensão das atividades presenciais.
#
# - **Menor volume em relação à graduação:**
#   O volume de empréstimos dos alunos de pós-graduação é significativamente menor do que o dos alunos de graduação, refletindo o perfil e as necessidades desse grupo.

# %% [markdown]
# DIA 6

# %%
cadastro_usuarios_antes_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Até 2010',skiprows=1)
cadastro_usuarios_depois_2010 = pd.read_excel('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/matricula_alunos.xlsx',
                                        sheet_name='Após 2010',skiprows=1)

# %%
cadastro_usuarios_antes_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_depois_2010.columns = ['matricula_ou_siape','tipo_vinculo_usuario','curso']
cadastro_usuarios_excel = cadastro_usuarios = pd.concat([cadastro_usuarios_antes_2010,cadastro_usuarios_depois_2010])

# %%
cadastro_usuarios_json = pd.read_json('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_6-Novos_dados_novas_analises/Datasets/cadastro_alunos.json')
cadastro_usuarios_json
# Out:
#      tipo_curso                                          registros
# 0     GRADUACAO  [{"matricula_ou_siape": "2009029003.0", "tipo_...
# 1  POSGRADUACAO  [{"matricula_ou_siape": "2008112114.0", "tipo_...

# %%
cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])
# Out:
# /var/folders/j9/n2mxm5tj18qd3qgjyq5l1b440000gn/T/ipykernel_10951/773441504.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   cadastro_usuarios_graduacao_json = pd.read_json(cadastro_usuarios_json.registros[0])

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  int64
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.4+ MB

# %%
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_graduacao_json.matricula_ou_siape = cadastro_usuarios_graduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_graduacao_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62802 entries, 0 to 62801
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   matricula_ou_siape    62802 non-null  string
#  1   tipo_vinculo_usuario  62802 non-null  object
#  2   curso                 62802 non-null  object
# dtypes: object(2), string(1)
# memory usage: 1.4+ MB

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_graduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape tipo_vinculo_usuario                 curso
# 0            190001688.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 1            199014489.0   ALUNO DE GRADUAÇÃO   CIÊNCIAS BIOLÓGICAS
# 2            199735674.0   ALUNO DE GRADUAÇÃO            MATEMÁTICA
# 3            199812431.0   ALUNO DE GRADUAÇÃO                LETRAS
# 4            199823670.0   ALUNO DE GRADUAÇÃO              ECOLOGIA
# ...                  ...                  ...                   ...
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72798      20200039601.0   ALUNO DE GRADUAÇÃO  ENGENHARIA FLORESTAL
# 72799      20200132517.0   ALUNO DE GRADUAÇÃO             AGRONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO       BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO               DIREITO
#
# [72802 rows x 3 columns]

# %%
matricula_data_de_emprestimo = emprestimos.query("tipo_vinculo_usuario == 'ALUNO DE GRADUAÇÃO'")
matricula_data_de_emprestimo = matricula_data_de_emprestimo.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo = matricula_data_de_emprestimo.query('data_emprestimo > 2015')
matricula_data_de_emprestimo = matricula_data_de_emprestimo.reset_index(drop=True)
matricula_data_de_emprestimo
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2013021576.0 2015-01-02 09:16:49.566
# 1            2014026648.0 2015-01-02 09:44:42.808
# 2            2014026648.0 2015-01-02 09:44:43.127
# 3            2010049586.0 2015-01-02 10:11:09.837
# 4            2014021454.0 2015-01-02 10:19:38.087
# ...                   ...                     ...
# 788099      20190154579.0 2020-03-18 16:26:20.477
# 788100      20160129109.0 2020-03-18 16:41:28.500
# 788101      20160129109.0 2020-03-18 16:41:28.588
# 788102      20160129109.0 2020-03-18 16:41:28.662
# 788103      20160129109.0 2020-03-18 16:41:28.713
#
# [788104 rows x 2 columns]

# %%
matricula_data_de_emprestimo.isna().sum()
# Out:
# matricula_ou_siape    0
# data_emprestimo       0
# dtype: int64

# %%
matricula_data_de_emprestimo = matricula_data_de_emprestimo.dropna()

# %%
cadastro_usuarios_cursos_selecionados = cadastro_usuarios_cursos.query("curso == ['BIBLIOTECONOMIA','CIÊNCIAS SOCIAIS','COMUNICAÇÃO SOCIAL','DIREITO','FILOSOFIA','PEDAGOGIA']")
cadastro_usuarios_cursos_selecionados
# Out:
#       matricula_ou_siape tipo_vinculo_usuario             curso
# 8            200031011.0   ALUNO DE GRADUAÇÃO           DIREITO
# 9            200045080.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 15           200115053.0   ALUNO DE GRADUAÇÃO  CIÊNCIAS SOCIAIS
# 18           200123382.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 19           200123730.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# ...                  ...                  ...               ...
# 72789      20200097481.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72796      20200107087.0   ALUNO DE GRADUAÇÃO         PEDAGOGIA
# 72797      20200012706.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72800      20200009344.0   ALUNO DE GRADUAÇÃO   BIBLIOTECONOMIA
# 72801      20200090284.0   ALUNO DE GRADUAÇÃO           DIREITO
#
# [18833 rows x 3 columns]

# %%
cadastro_usuarios_cursos_selecionados = matricula_data_de_emprestimo.merge(cadastro_usuarios_cursos_selecionados)
cadastro_usuarios_cursos_selecionados
# Out:
#        matricula_ou_siape         data_emprestimo tipo_vinculo_usuario  \
# 0            2014021454.0 2015-01-02 10:19:38.087   ALUNO DE GRADUAÇÃO
# 1            2013018187.0 2015-01-02 10:25:40.883   ALUNO DE GRADUAÇÃO
# 2            2014029499.0 2015-01-02 12:26:43.571   ALUNO DE GRADUAÇÃO
# 3            2014029499.0 2015-01-02 12:26:43.840   ALUNO DE GRADUAÇÃO
# 4            2014029499.0 2015-01-02 12:26:44.750   ALUNO DE GRADUAÇÃO
# ...                   ...                     ...                  ...
# 211643      20200090284.0 2020-03-17 20:23:54.966   ALUNO DE GRADUAÇÃO
# 211644      20180113385.0 2020-03-17 21:20:47.278   ALUNO DE GRADUAÇÃO
# 211645      20190150079.0 2020-03-18 13:43:53.220   ALUNO DE GRADUAÇÃO
# 211646      20190150079.0 2020-03-18 13:43:53.389   ALUNO DE GRADUAÇÃO
# 211647      20190150079.0 2020-03-18 13:43:53.456   ALUNO DE GRADUAÇÃO
#
#                    curso
# 0              FILOSOFIA
# 1                DIREITO
# 2       CIÊNCIAS SOCIAIS
# ...

# %%
cadastro_usuarios_cursos_selecionados.data_emprestimo = cadastro_usuarios_cursos_selecionados.data_emprestimo.dt.year

# %%
emprestimos_cursos_selecionados = cadastro_usuarios_cursos_selecionados.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_cursos_selecionados.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_cursos_selecionados
# Out:
#      ANO               CURSO  QUANTIDADE_EMPRESTIMOS
# 0   2017  COMUNICAÇÃO SOCIAL                    8239
# 1   2016  COMUNICAÇÃO SOCIAL                    7947
# 2   2017             DIREITO                    7862
# 3   2016           FILOSOFIA                    7576
# 4   2015     BIBLIOTECONOMIA                    7556
# 5   2015             DIREITO                    7435
# 6   2017           PEDAGOGIA                    7434
# 7   2017           FILOSOFIA                    7389
# 8   2016             DIREITO                    7307
# 9   2017     BIBLIOTECONOMIA                    7279
# 10  2015    CIÊNCIAS SOCIAIS                    7238
# 11  2015           PEDAGOGIA                    7189
# 12  2016           PEDAGOGIA                    7153
# 13  2018             DIREITO                    7022
# 14  2016     BIBLIOTECONOMIA                    6984
# 15  2015           FILOSOFIA                    6950
# 16  2018  COMUNICAÇÃO SOCIAL                    6950
# ...

# %%
emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS',
        fill_value = '-',
        aggfunc= sum,
        margins = True,
        margins_name = 'TOTAL',
)
emprestimos_tipo_usuario_curso_pivot
# Out:
# /var/folders/j9/n2mxm5tj18qd3qgjyq5l1b440000gn/T/ipykernel_10951/994587600.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
# /var/folders/j9/n2mxm5tj18qd3qgjyq5l1b440000gn/T/ipykernel_10951/994587600.py:1: FutureWarning: The provided callable <built-in function sum> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   emprestimos_tipo_usuario_curso_pivot = emprestimos_cursos_selecionados.pivot_table(
# ...

# %% [markdown]
# DIA 7

# %%
cadastro_usuarios_posgraduacao_json = pd.read_json(cadastro_usuarios_json.registros[1])
# Out:
# /var/folders/j9/n2mxm5tj18qd3qgjyq5l1b440000gn/T/ipykernel_10951/279755034.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   cadastro_usuarios_posgraduacao_json = pd.read_json(cadastro_usuarios_json.registros[1])

# %%
cadastro_usuarios_posgraduacao_json
# Out:
#        matricula_ou_siape    tipo_vinculo_usuario  \
# 0              2008112114  ALUNO DE PÓS-GRADUAÇÃO
# 1              2008106583  ALUNO DE PÓS-GRADUAÇÃO
# 2              2011101417  ALUNO DE PÓS-GRADUAÇÃO
# 3              2011113122  ALUNO DE PÓS-GRADUAÇÃO
# 4              2010110903  ALUNO DE PÓS-GRADUAÇÃO
# ...                   ...                     ...
# 19435         20201013501  ALUNO DE PÓS-GRADUAÇÃO
# 19436         20201014062  ALUNO DE PÓS-GRADUAÇÃO
# 19437         20201017690  ALUNO DE PÓS-GRADUAÇÃO
# 19438         20201014465  ALUNO DE PÓS-GRADUAÇÃO
# 19439         20201014993  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %%
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('float')
cadastro_usuarios_posgraduacao_json.matricula_ou_siape = cadastro_usuarios_posgraduacao_json.matricula_ou_siape.astype('string')

# %%
cadastro_usuarios_cursos = pd.concat([cadastro_usuarios_excel,cadastro_usuarios_posgraduacao_json],ignore_index=True)
cadastro_usuarios_cursos
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0            190001688.0      ALUNO DE GRADUAÇÃO
# 1            199014489.0      ALUNO DE GRADUAÇÃO
# 2            199735674.0      ALUNO DE GRADUAÇÃO
# 3            199812431.0      ALUNO DE GRADUAÇÃO
# 4            199823670.0      ALUNO DE GRADUAÇÃO
# ...                  ...                     ...
# 29435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 29436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 29437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 29438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 29439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                                  MATEMÁTICA
# 1                         CIÊNCIAS BIOLÓGICAS
# 2                                  MATEMÁTICA
# 3                                      LETRAS
# 4                                    ECOLOGIA
# ...                                       ...
# ...

# %%
cadastro_usuarios_cursos_pos_graduacao = cadastro_usuarios_posgraduacao_json.query("tipo_vinculo_usuario == 'ALUNO DE PÓS-GRADUAÇÃO'")
cadastro_usuarios_cursos_pos_graduacao
# Out:
#       matricula_ou_siape    tipo_vinculo_usuario  \
# 0           2008112114.0  ALUNO DE PÓS-GRADUAÇÃO
# 1           2008106583.0  ALUNO DE PÓS-GRADUAÇÃO
# 2           2011101417.0  ALUNO DE PÓS-GRADUAÇÃO
# 3           2011113122.0  ALUNO DE PÓS-GRADUAÇÃO
# 4           2010110903.0  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...
# 19435      20201013501.0  ALUNO DE PÓS-GRADUAÇÃO
# 19436      20201014062.0  ALUNO DE PÓS-GRADUAÇÃO
# 19437      20201017690.0  ALUNO DE PÓS-GRADUAÇÃO
# 19438      20201014465.0  ALUNO DE PÓS-GRADUAÇÃO
# 19439      20201014993.0  ALUNO DE PÓS-GRADUAÇÃO
#
#                                         curso
# 0                      CIÊNCIAS ODONTOLÓGICAS
# 1                      ENGENHARIA DE SOFTWARE
# 2                     ARQUITETURA E URBANISMO
# 3                                   FILOSOFIA
# 4                               ARTES CÊNICAS
# ...                                       ...
# ...

# %%
matricula_data_de_emprestimo_pos_graduacao = emprestimos.loc[:,['matricula_ou_siape','data_emprestimo']]
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.query('data_emprestimo > 2017')
matricula_data_de_emprestimo_pos_graduacao = matricula_data_de_emprestimo_pos_graduacao.reset_index(drop=True)
matricula_data_de_emprestimo_pos_graduacao
# Out:
#        matricula_ou_siape         data_emprestimo
# 0            2014035816.0 2017-01-02 08:01:14.113
# 1           20161011168.0 2017-01-02 08:29:46.722
# 2           20161011168.0 2017-01-02 08:29:46.794
# 3           20161011168.0 2017-01-02 08:46:42.991
# 4           20161011168.0 2017-01-02 08:46:43.400
# ...                   ...                     ...
# 609948          3067431.0 2020-05-05 19:51:06.059
# 609949          3067431.0 2020-05-05 19:51:06.135
# 609950          3067431.0 2020-05-05 19:51:06.164
# 609951      20201014993.0 2020-06-09 11:54:02.669
# 609952      20201014993.0 2020-06-09 11:54:02.852
#
# [609953 rows x 2 columns]

# %%
emprestimos_pos_graduacao_desde_2017 = matricula_data_de_emprestimo_pos_graduacao.merge(cadastro_usuarios_cursos_pos_graduacao)
emprestimos_pos_graduacao_desde_2017
# Out:
#       matricula_ou_siape         data_emprestimo    tipo_vinculo_usuario  \
# 0          20161011168.0 2017-01-02 08:29:46.722  ALUNO DE PÓS-GRADUAÇÃO
# 1          20161011168.0 2017-01-02 08:29:46.794  ALUNO DE PÓS-GRADUAÇÃO
# 2          20161011168.0 2017-01-02 08:46:42.991  ALUNO DE PÓS-GRADUAÇÃO
# 3          20161011168.0 2017-01-02 08:46:43.400  ALUNO DE PÓS-GRADUAÇÃO
# 4          20161013903.0 2017-01-02 09:41:45.823  ALUNO DE PÓS-GRADUAÇÃO
# ...                  ...                     ...                     ...
# 92057      20191017055.0 2020-03-19 14:41:57.754  ALUNO DE PÓS-GRADUAÇÃO
# 92058      20191017055.0 2020-03-19 14:42:56.670  ALUNO DE PÓS-GRADUAÇÃO
# 92059      20191017055.0 2020-03-19 14:43:40.666  ALUNO DE PÓS-GRADUAÇÃO
# 92060      20201014993.0 2020-06-09 11:54:02.669  ALUNO DE PÓS-GRADUAÇÃO
# 92061      20201014993.0 2020-06-09 11:54:02.852  ALUNO DE PÓS-GRADUAÇÃO
#
#                   curso
# 0             FILOSOFIA
# 1             FILOSOFIA
# ...

# %%
emprestimos_pos_graduacao_desde_2017.data_emprestimo = emprestimos_pos_graduacao_desde_2017.data_emprestimo.dt.year

# %%
emprestimos_pos_graduacao_desde_2017 = emprestimos_pos_graduacao_desde_2017.iloc[:,[1,3]].value_counts().reset_index()
emprestimos_pos_graduacao_desde_2017.columns = ['ANO','CURSO','QUANTIDADE_EMPRESTIMOS']
emprestimos_pos_graduacao_desde_2017.head()
# Out:
#     ANO                           CURSO  QUANTIDADE_EMPRESTIMOS
# 0  2018          CIÊNCIAS ODONTOLÓGICAS                    2540
# 1  2017                   ADMINISTRAÇÃO                    2538
# 2  2017          ENGENHARIA DE SOFTWARE                    2477
# 3  2017               CIÊNCIAS DA SAÚDE                    2434
# 4  2017  CIÊNCIA, TECNOLOGIA E INOVAÇÃO                    2415

# %%
emprestimos_pos_graduacao_e_curso_pivot = emprestimos_pos_graduacao_desde_2017.pivot_table(
        index = 'CURSO',
        columns = 'ANO',
        values = 'QUANTIDADE_EMPRESTIMOS'
)
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0
# DESIGN                                  2272.0  1838.0  1841.0  254.0
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0
# ENGENHARIA DE SOFTWARE                  2477.0  2222.0  1887.0  264.0
# ...

# %%
previsao_2022 = pd.read_table('https://github.com/FranciscoFoz/7_Days_of_Code_Alura-Python-Pandas/raw/main/Dia_7-Apresentando_resultados_em_HTML/Dataset/previsao')

# %%
previsao_2022 = previsao_2022['curso previsao_2022'].str.split(' ',expand=True)
previsao_2022
# Out:
#                                          0     1
# 0                            administracao  1905
# 1                  arquitetura_e_urbanismo  1896
# 2                            artes_cenicas  1920
# 3                           bioinformatica  2302
# 4                               bioquimica  2090
# 5        ciencia_e_engenharia_de_materiais  2010
# 6            ciencia_tecnologia_e_inovacao  1960
# 7                        ciencias_da_saude  1730
# 8                   ciencias_odontologicas  2405
# 9                                   design  1900
# 10                        engenharia_civil  1920
# 11                     engenharia_software  1890
# 12                               filosofia  1903
# 13  gestao_da_informacao_e_do_conhecimento  1855

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0
# DESIGN                                  2272.0  1838.0  1841.0  254.0
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0
# ENGENHARIA DE SOFTWARE                  2477.0  2222.0  1887.0  264.0
# ...

# %%
previsao_2022.index = emprestimos_pos_graduacao_e_curso_pivot.index
emprestimos_pos_graduacao_e_curso_pivot['2022'] = previsao_2022.iloc[:,1]
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %%
emprestimos_pos_graduacao_e_curso_pivot['2022'] = emprestimos_pos_graduacao_e_curso_pivot['2022'].astype('int')

# %%
emprestimos_pos_graduacao_e_curso_pivot
# Out:
# ANO                                       2017    2018    2019   2020  2022
# CURSO
# ADMINISTRAÇÃO                           2538.0  2316.0  1692.0  269.0  1905
# ARQUITETURA E URBANISMO                 2209.0  1917.0  1818.0  257.0  1896
# ARTES CÊNICAS                           2115.0  2082.0  1812.0  229.0  1920
# BIOINFORMÁTICA                          2190.0  1914.0  1825.0  263.0  2302
# BIOQUÍMICA                              2294.0  1944.0  2057.0  272.0  2090
# CIÊNCIA E ENGENHARIA DE MATERIAIS       2316.0  2110.0  2008.0  328.0  2010
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          2415.0  2365.0  2026.0  303.0  1960
# CIÊNCIAS DA SAÚDE                       2434.0  1986.0  1825.0  234.0  1730
# CIÊNCIAS ODONTOLÓGICAS                  2414.0  2540.0  2134.0  352.0  2405
# DESIGN                                  2272.0  1838.0  1841.0  254.0  1900
# ENGENHARIA CIVIL                        2399.0  2089.0  1989.0  254.0  1920
# ...

# %%
def diferenca_percentual_ano_anterior(x,y):
  return round(((x / y * 100) - 100),2)

# %%
percentual_2018 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,0])
percentual_2019 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,1])
percentual_2022 = diferenca_percentual_ano_anterior(emprestimos_pos_graduacao_e_curso_pivot.iloc[:,3],emprestimos_pos_graduacao_e_curso_pivot.iloc[:,2])

# %%
percentual = pd.DataFrame({'2018':percentual_2018,
                           '2019':percentual_2019,
                           '2022':percentual_2022})
percentual
# Out:
#                                          2018   2019   2022
# CURSO
# ADMINISTRAÇÃO                           -8.75 -26.94 -84.10
# ARQUITETURA E URBANISMO                -13.22  -5.16 -85.86
# ARTES CÊNICAS                           -1.56 -12.97 -87.36
# BIOINFORMÁTICA                         -12.60  -4.65 -85.59
# BIOQUÍMICA                             -15.26   5.81 -86.78
# CIÊNCIA E ENGENHARIA DE MATERIAIS       -8.89  -4.83 -83.67
# CIÊNCIA, TECNOLOGIA E INOVAÇÃO          -2.07 -14.33 -85.04
# CIÊNCIAS DA SAÚDE                      -18.41  -8.11 -87.18
# CIÊNCIAS ODONTOLÓGICAS                   5.22 -15.98 -83.51
# DESIGN                                 -19.10   0.16 -86.20
# ENGENHARIA CIVIL                       -12.92  -4.79 -87.23
# ENGENHARIA DE SOFTWARE                 -10.29 -15.08 -86.01
# FILOSOFIA                               -5.62 -13.43 -82.97
# GESTÃO DA INFORMAÇÃO E DO CONHECIMENTO -16.55  -6.35 -85.77

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

# %%
percentual
# Out:
#                                      Curso   2018   2019   2022
# 0                            Administração  -8.75 -26.94 -84.10
# 1                  Arquitetura e urbanismo -13.22  -5.16 -85.86
# 2                            Artes cênicas  -1.56 -12.97 -87.36
# 3                           Bioinformática -12.60  -4.65 -85.59
# 4                               Bioquímica -15.26   5.81 -86.78
# 5        Ciência e engenharia de materiais  -8.89  -4.83 -83.67
# 6           Ciência, tecnologia e inovação  -2.07 -14.33 -85.04
# 7                        Ciências da saúde -18.41  -8.11 -87.18
# 8                   Ciências odontológicas   5.22 -15.98 -83.51
# 9                                   Design -19.10   0.16 -86.20
# 10                        Engenharia civil -12.92  -4.79 -87.23
# 11                  Engenharia de software -10.29 -15.08 -86.01
# 12                               Filosofia  -5.62 -13.43 -82.97
# 13  Gestão da informação e do conhecimento -16.55  -6.35 -85.77

# %%
th_props = [
  ('font-size', '1.4rem'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'whitesmoke'),
  ('background-color', '#001692'),
  ('border-radius', '0.25rem'),
  ('box-shadow','0 0 1rem gray')
  ]

td_props = [
  ('font-size', '1rem'),
  ('padding','0.5rem'),
  ('text-align', 'left'),
  ('font-weight', 'bold'),
  ('border-bottom','0.1rem solid lightgray')
  ]

styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]

# %%
pip install jinja2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
percentual.style.text_gradient(cmap='RdYlGn', low=1, axis=1, vmax=0.1, vmin=0) \
    .format('{:.2f} %', subset=['2018', '2019', '2022']) \
    .hide(axis="index") \
    .set_table_styles(styles) \
    .to_html('teste.html', doctype_html=True, table_attributes='ALIGN=LEFT WIDTH=50% CELLSPACING=5')

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()

# %%
percentual.reset_index(inplace=True)
percentual.columns = percentual.columns.str.capitalize()
percentual.Curso = percentual.Curso.str.capitalize()
